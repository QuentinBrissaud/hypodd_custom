# %%
import pandas as pd
import numpy as np

# %%
file = './data/starting-station-Malyn.csv'
stations = pd.read_csv(file, header=[0],)

file = './data/starting-event-Malyn.csv'
events = pd.read_csv(file, header=[0],)

file = './data/starting-phase-Malyn.csv'
phases = pd.read_csv(file, header=[0],)
