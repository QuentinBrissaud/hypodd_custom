# %%
import glob
from hypoddpy import HypoDDRelocator


# Init the relocator with the working directory and some necessary
# configuration values.
#
# The working dir is where all the working files and some output files will be
# stored.
# All the other attributes are related to the cross correlation and should be
# self-explanatory.
relocator = HypoDDRelocator(working_dir="relocator_working_dir",
    cc_time_before=0.05,
    cc_time_after=0.2,
    cc_maxlag=0.1,
    cc_filter_min_freq=1.0,
    cc_filter_max_freq=20.0,
    cc_p_phase_weighting={"Z": 1.0},
    cc_s_phase_weighting={"Z": 1.0, "E": 1.0, "N": 1.0},
    cc_min_allowed_cross_corr_coeff=0.4)

# Add the necessary files. Call a function multiple times if necessary.
relocator.add_event_files(glob.glob("events/*.xml"))
#relocator.add_waveform_files(glob.glob("waveform/*.mseed"))
relocator.add_station_files(glob.glob("station/*.xml"))

# Setup the velocity model. This is just a constant velocity model.
relocator.setup_velocity_model(
    model_type="layered_p_velocity_with_constant_vp_vs_ratio",
    layer_tops=[(-10000, 5.8)],
    vp_vs_ratio=1.73)

# Start the relocation with the desired output file.
relocator.start_relocation(output_event_file="relocated_events.xml")
# Out:
# >>> Starting relocator...
# >>> Parsing stations...
# >>> Done parsing stations.
# >>> Created station.dat input file.
# >>> Reading all events...
# >>> Reading all events successful.
# >>> 0 picks discarded because of unavailable station information.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 34
#      28 relocator.setup_velocity_model(
#      29     model_type="layered_p_velocity_with_constant_vp_vs_ratio",
#      30     layer_tops=[(-10000, 5.8)],
#      31     vp_vs_ratio=1.73)
#      33 # Start the relocation with the desired output file.
# ---> 34 relocator.start_relocation(output_event_file="relocated_events.xml")
#
# File ~\Documents\hypoDDpy\hypoddpy\hypodd_relocator.py:168, in HypoDDRelocator.start_relocation(self, output_event_file, output_cross_correlation_file, create_plots)
#     166 self._write_station_input_file()
#     167 self._read_event_information()
# --> 168 self._write_ph2dt_inp_file()
#     169 self._create_event_id_map()
#     170 self._write_catalog_input_file()
#
# File ~\Documents\hypoDDpy\hypoddpy\hypodd_relocator.py:656, in HypoDDRelocator._write_ph2dt_inp_file(self)
#     654     # station elevation is in meter.
#     655     depths.append(station["elevation"] / 1000.0)
# --> 656 lat_range = (max(lats) - min(lats)) * 111.0
#     657 long_range = (max(longs) - min(longs)) * 111.0
#     658 depth_range = max(depths) - min(depths)
#
# ValueError: max() arg is an empty sequence
